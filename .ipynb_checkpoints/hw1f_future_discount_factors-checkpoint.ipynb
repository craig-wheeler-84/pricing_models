# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('usd_curve.csv')
times = data['t'].values
df0 = data['df'].values

class HullWhite():
    def __init__(self, a, sigma, timesteps, x0=0):
        self.a = a
        self.sigma = sigma
        self.timesteps = timesteps
        self.x0 = x0
        
    def hw_exp(self, x, t1, t2):
        return x * np.exp(-self.a * (t2 - t1))
    
    def hw_var(self, t1, t2):
        return self.sigma ** 2 * (1 - np.exp(-2 * self.a * (t2 - t1))) / (2 * self.a)

    def MC(self, sims):
        x = np.zeros((sims, self.timesteps))
        for i in range(sims):
            x[i,0] = self.x0
            for j in range(1, self.timesteps):
                Z1 = np.random.normal(0,1)
                x[i,j] = self.hw_exp(x[i,j-1], j-1, j) + Z1 * (self.hw_var(j-1,j) ** 0.5)
        return x

# %%
class DiscountFactors():
    def __init__(self, a, sigma):
        self.a = a
        self.sigma = sigma
        
    def q_t(self, t, T):
         return (1 - np.exp(-self.a * (T - t))) / self.a

    def cov(self, t_i, t_j):
        return self.sigma ** 2 * (np.exp(-self.a * abs(t_j - t_i)) - np.exp(-self.a * (t_j + t_i))) / (2 * self.a)
 
    def hw_phi(self, q_val, cov_val):
        return sum(q * cov for q, cov in zip(q_values, cov_values))

    def hw_gamma(self, tn):
        return 0.5 * self.cov(tn, tn)

    def interpolated_df(self, t, time, df):
        return np.interp(t, time, df0)
    
    def df(self, t_n, T, x_tn, q_val, cov_val):
        B_tn = self.interpolated_df(t_n, times, df0)
        B_T = self.interpolated_df(T, times, df0)
        if t_n == 0:
            discount_factor = B_T / B_tn 
        else:
            phi = self.hw_phi(q_val, cov_val)
            gamma = self.hw_gamma(t_n)
            q_tn = self.q_t(t_n, T)
            discount_factor = (B_T / B_tn) * np.exp(-(x_tn + phi) * q_tn - gamma * (q_tn ** 2))
        return discount_factor

# %%
# Testing Hull White

a = 0.1
x0 = 0
sigma = 0.002

timesteps = 5

# MC Parameters
sims = 2
T = 5
dt = T / timesteps  
hw_timesteps = int(T / dt) + 1

hw = HullWhite(a, sigma, hw_timesteps, x0)
simulated_paths = hw.MC(sims)
hwdf = DiscountFactors(a, sigma)

#print (simulated_paths)
#print (hw_timesteps)
#print (dt)

for i in range(sims):
    plt.plot(simulated_paths[i])
plt.xlabel('Time Step')
plt.ylabel('xe')
plt.title('Hull White Simulations')
plt.show()

# %%
q_values = []
cov_values = []
for x in range(timesteps + 1):
    q_val1 = hwdf.q_t(x, x + 1)
    cov1 = hwdf.cov(x, timesteps + 1)
    q_values.append(q_val1)
    cov_values.append(cov1)

result = sum(q * cov for q, cov in zip(q_values, cov_values))

for i in range(sims):
    x_tn_values = simulated_paths[i]

    for t_n in range(hw_timesteps):
        t = t_n * dt  
        T = T         
        q_val = hwdf.q_t(t, T)
        cov_val = hwdf.cov(t, T)
        discount_factor = hwdf.df(t, T, x_tn_values[t_n], q_val, cov_val)  
        
discount_factors = np.zeros((sims, hw_timesteps))        

       
for i in range(sims):
    x_tn_values = simulated_paths[i]
    for t_n in range(hw_timesteps):
        t = t_n * dt  
        T = T      
        q_val = hwdf.q_t(t, T)
        cov_val = hwdf.cov(t, T)
        discount_factors[i, t_n] = hwdf.df(t, T, x_tn_values[t_n], q_val, cov_val)

#print(discount_factors)        
       
for i in range(sims):
    plt.plot(np.arange(hw_timesteps) * dt, discount_factors[i], label=f'Simulation {i+1}')

plt.xlabel('Time')
plt.ylabel('Forward Discount Factor')
plt.legend()
plt.show()

# %%
# get all the discount factors to price a swap


x_tn_array = np.array([simulated_paths[i] for i in range(sims)])

#print(x_tn_array)

df = np.zeros((sims, timesteps, timesteps))



for i in range(sims):
    for j in range(timesteps):
        for k in range(j, timesteps):
            df[i, 0, k] = df0[k]
            df[i, j, k] = hwdf.df(k, T, x_tn_array[i,k], q_val, cov_val)

print(df)
# Out:
# [[[0.978506   0.999998   0.999988   0.999968   0.999863  ]
#   [0.         0.98422807 0.98393273 0.98316516 0.9890981 ]
#   [0.         0.         0.98393273 0.98316516 0.9890981 ]
#   [0.         0.         0.         0.98316516 0.9890981 ]
#   [0.         0.         0.         0.         0.9890981 ]]
#
#  [[0.978506   0.999998   0.999988   0.999968   0.999863  ]
#   [0.         0.9765574  0.97348915 0.97756253 0.98543452]
#   [0.         0.         0.97348915 0.97756253 0.98543452]
#   [0.         0.         0.         0.97756253 0.98543452]
#   [0.         0.         0.         0.         0.98543452]]]

# %%
f = (4,5,6,7,8)

f[3] = 10

print(f)

cashflow = sum([f[i] * 0.5 for i in range(len(f))])
f = [f[i] * 0.5 for i in range(len(f))]

print(cashflow)
print(f)

f[3] = 1

print(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 f = (4,5,6,7,8)
# ----> 3 f[3] = 10
#       5 print(f)
#       7 cashflow = sum([f[i] * 0.5 for i in range(len(f))])
#
# TypeError: 'tuple' object does not support item assignment

# %%
#need to rewrite this so it is consistent with LMM, when that is ready

def swap_pricer(Notional, fixed_Rate, Maturity, T_n, sims, hwdf, times, df):
    
    fixed_cash_flows = [fixed_Rate] * Maturity
    present_values = np.zeros((sims, len(fixed_cash_flows)))

    for i in range(sims):
        for t in range(T_n, Maturity):  # Start t from T_n
            t_1 = t + 1
            T = Maturity
           
            x_tn_values = np.zeros(Maturity)
            x_tn_values[T_n] = hw.x0  # Initialize x_tn_values for each T_n

            # Calculate x_tn_values for the entire path
            for j in range(T_n + 1, Maturity):
                Z1 = np.random.normal(0, 1)
                x_tn_values[j] = hw.hw_exp(x_tn_values[j - 1], j - 1, j) + Z1 * (hw.hw_var(j - 1, j) ** 0.5)
           
            frw_discount_factor = hwdf.df(t, t_1, x_tn_values[t], q_val, cov_val)
           
            # Check if frw_discount_factor is valid before taking the logarithm
            if frw_discount_factor > 0:
                Forward_rate = -np.log(frw_discount_factor) / (t_1 - t)
            else:
                Forward_rate = 0  # Set to a default value or handle this case as needed
           
            df_tn = hwdf.df(T_n, t_1, x_tn_values[T_n], q_val, cov_val)

            fixed_present_value = (fixed_cash_flows[t] * Notional) * df_tn
            floating_present_value = (Forward_rate * Notional) * df_tn

            present_values[i, t] = (floating_present_value - fixed_present_value)
           
            df_tn = round(df_tn, 3)
            Forward_rate = round(Forward_rate, 3)
            frw_discount_factor = round(frw_discount_factor, 3)
           
            # Print the desired output
            print(f"Sim {i+1}, t_n = {T_n}, t = {t}, t_1 = {t_1}, T = {mat}: df = {df_tn}, Fwd = {Forward_rate},  frw_df = {frw_discount_factor}")

    swap_values = present_values.sum(axis=1)

    return swap_values

mat = 5

for T_n in range(mat):
    swap_values = swap_pricer(10000, 0.001, mat, T_n, sims, hwdf, times, df)
    for sim in range(sims):
        print(f"Simulation {sim+1}, T_n = {T_n}: Total Swap Value = {swap_values[sim]}")

Notional = 10000
# Out:
# Sim 1, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 1, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.001,  frw_df = 0.999
# Sim 1, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.005,  frw_df = 0.995
# Sim 1, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = -0.001,  frw_df = 1.001
# Sim 1, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.004,  frw_df = 0.996
# Sim 2, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 2, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.001,  frw_df = 0.999
# Sim 2, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = -0.002,  frw_df = 1.002
# Sim 2, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.004,  frw_df = 0.996
# Sim 2, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.01,  frw_df = 0.99
# Sim 3, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 3, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.003,  frw_df = 0.997
# Sim 3, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.006,  frw_df = 0.994
# Sim 3, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.01,  frw_df = 0.99
# Sim 3, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.003,  frw_df = 0.997
# Sim 4, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 4, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = -0.0,  frw_df = 1.0
# Sim 4, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.006,  frw_df = 0.994
# Sim 4, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.007,  frw_df = 0.993
# Sim 4, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.011,  frw_df = 0.989
# Sim 5, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 5, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.002,  frw_df = 0.998
# Sim 5, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.003,  frw_df = 0.997
# Sim 5, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.005,  frw_df = 0.995
# Sim 5, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.01,  frw_df = 0.99
# Sim 6, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 6, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.008,  frw_df = 0.992
# Sim 6, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.003,  frw_df = 0.997
# Sim 6, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.005,  frw_df = 0.995
# Sim 6, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.01,  frw_df = 0.99
# Sim 7, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 7, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.001,  frw_df = 0.999
# Sim 7, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.004,  frw_df = 0.996
# Sim 7, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.004,  frw_df = 0.996
# Sim 7, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.011,  frw_df = 0.989
# Sim 8, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 8, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 8, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = -0.001,  frw_df = 1.001
# Sim 8, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.005,  frw_df = 0.995
# Sim 8, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.011,  frw_df = 0.989
# Sim 9, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 9, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.002,  frw_df = 0.998
# Sim 9, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.006,  frw_df = 0.994
# Sim 9, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.01,  frw_df = 0.99
# Sim 9, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.004,  frw_df = 0.996
# Sim 10, t_n = 0, t = 0, t_1 = 1, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 10, t_n = 0, t = 1, t_1 = 2, T = 5: df = 0.995, Fwd = 0.001,  frw_df = 0.999
# Sim 10, t_n = 0, t = 2, t_1 = 3, T = 5: df = 0.991, Fwd = 0.003,  frw_df = 0.997
# Sim 10, t_n = 0, t = 3, t_1 = 4, T = 5: df = 0.986, Fwd = 0.008,  frw_df = 0.992
# Sim 10, t_n = 0, t = 4, t_1 = 5, T = 5: df = 0.979, Fwd = 0.005,  frw_df = 0.995
# Simulation 1, T_n = 0: Total Swap Value = 70.66404533071966
# Simulation 2, T_n = 0: Total Swap Value = 105.4484556169532
# Simulation 3, T_n = 0: Total Swap Value = 196.49180456391286
# Simulation 4, T_n = 0: Total Swap Value = 205.51134916338117
# Simulation 5, T_n = 0: Total Swap Value = 181.96364019229924
# Simulation 6, T_n = 0: Total Swap Value = 240.01089417787975
# Simulation 7, T_n = 0: Total Swap Value = 174.24204887350658
# Simulation 8, T_n = 0: Total Swap Value = 168.36376370294937
# Simulation 9, T_n = 0: Total Swap Value = 206.09261590927983
# Simulation 10, T_n = 0: Total Swap Value = 148.70242726822508
# Sim 1, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 1, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.004,  frw_df = 0.996
# Sim 1, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.0,  frw_df = 1.0
# Sim 1, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.008,  frw_df = 0.992
# Sim 2, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 2, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.004,  frw_df = 0.996
# Sim 2, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.005,  frw_df = 0.995
# Sim 2, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.008,  frw_df = 0.992
# Sim 3, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 3, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.005,  frw_df = 0.995
# Sim 3, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.005,  frw_df = 0.995
# Sim 3, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.011,  frw_df = 0.989
# Sim 4, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 4, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.005,  frw_df = 0.995
# Sim 4, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.005,  frw_df = 0.995
# Sim 4, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.007,  frw_df = 0.993
# Sim 5, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 5, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.004,  frw_df = 0.996
# Sim 5, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.005,  frw_df = 0.995
# Sim 5, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.007,  frw_df = 0.993
# Sim 6, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 6, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.005,  frw_df = 0.995
# Sim 6, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.001,  frw_df = 0.999
# Sim 6, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.008,  frw_df = 0.992
# Sim 7, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 7, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.004,  frw_df = 0.996
# Sim 7, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.007,  frw_df = 0.993
# Sim 7, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.009,  frw_df = 0.991
# Sim 8, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 8, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.005,  frw_df = 0.995
# Sim 8, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.008,  frw_df = 0.992
# Sim 8, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.013,  frw_df = 0.987
# Sim 9, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 9, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.003,  frw_df = 0.997
# Sim 9, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.006,  frw_df = 0.994
# Sim 9, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.011,  frw_df = 0.989
# Sim 10, t_n = 1, t = 1, t_1 = 2, T = 5: df = 0.997, Fwd = 0.003,  frw_df = 0.997
# Sim 10, t_n = 1, t = 2, t_1 = 3, T = 5: df = 0.994, Fwd = 0.001,  frw_df = 0.999
# Sim 10, t_n = 1, t = 3, t_1 = 4, T = 5: df = 0.989, Fwd = 0.003,  frw_df = 0.997
# Sim 10, t_n = 1, t = 4, t_1 = 5, T = 5: df = 0.981, Fwd = 0.008,  frw_df = 0.992
# Simulation 1, T_n = 1: Total Swap Value = 98.94328935641221
# Simulation 2, T_n = 1: Total Swap Value = 147.95581081702946
# Simulation 3, T_n = 1: Total Swap Value = 201.70665090104154
# Simulation 4, T_n = 1: Total Swap Value = 151.99105408708436
# Simulation 5, T_n = 1: Total Swap Value = 140.09199954874504
# Simulation 6, T_n = 1: Total Swap Value = 110.28593048298336
# Simulation 7, T_n = 1: Total Swap Value = 186.16800193605593
# Simulation 8, T_n = 1: Total Swap Value = 242.98249331751828
# Simulation 9, T_n = 1: Total Swap Value = 193.21462163831382
# Simulation 10, T_n = 1: Total Swap Value = 101.24704203705701
# Sim 1, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 1, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.005,  frw_df = 0.995
# Sim 1, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.005,  frw_df = 0.995
# Sim 2, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 2, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.003,  frw_df = 0.997
# Sim 2, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.006,  frw_df = 0.994
# Sim 3, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 3, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.004,  frw_df = 0.996
# Sim 3, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.011,  frw_df = 0.989
# Sim 4, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 4, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.005,  frw_df = 0.995
# Sim 4, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.008,  frw_df = 0.992
# Sim 5, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 5, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.003,  frw_df = 0.997
# Sim 5, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.007,  frw_df = 0.993
# Sim 6, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 6, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.006,  frw_df = 0.994
# Sim 6, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.009,  frw_df = 0.991
# Sim 7, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 7, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.003,  frw_df = 0.997
# Sim 7, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.006,  frw_df = 0.994
# Sim 8, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 8, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.005,  frw_df = 0.995
# Sim 8, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.003,  frw_df = 0.997
# Sim 9, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 9, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.001,  frw_df = 0.999
# Sim 9, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.009,  frw_df = 0.991
# Sim 10, t_n = 2, t = 2, t_1 = 3, T = 5: df = 0.996, Fwd = 0.004,  frw_df = 0.996
# Sim 10, t_n = 2, t = 3, t_1 = 4, T = 5: df = 0.991, Fwd = 0.006,  frw_df = 0.994
# Sim 10, t_n = 2, t = 4, t_1 = 5, T = 5: df = 0.984, Fwd = 0.006,  frw_df = 0.994
# Simulation 1, T_n = 2: Total Swap Value = 98.37677529710962
# Simulation 2, T_n = 2: Total Swap Value = 92.26659581528791
# Simulation 3, T_n = 2: Total Swap Value = 158.08799095440594
# Simulation 4, T_n = 2: Total Swap Value = 138.8932380787537
# Simulation 5, T_n = 2: Total Swap Value = 103.76483254589097
# Simulation 6, T_n = 2: Total Swap Value = 152.15214756702596
# Simulation 7, T_n = 2: Total Swap Value = 99.05470019402843
# Simulation 8, T_n = 2: Total Swap Value = 79.97396939400177
# Simulation 9, T_n = 2: Total Swap Value = 105.7519603697226
# Simulation 10, T_n = 2: Total Swap Value = 120.74126270180716
# Sim 1, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 1, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.009,  frw_df = 0.991
# Sim 2, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 2, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.008,  frw_df = 0.992
# Sim 3, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 3, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.007,  frw_df = 0.993
# Sim 4, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 4, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.01,  frw_df = 0.99
# Sim 5, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 5, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.006,  frw_df = 0.994
# Sim 6, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 6, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.006,  frw_df = 0.994
# Sim 7, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 7, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.005,  frw_df = 0.995
# Sim 8, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 8, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.005,  frw_df = 0.995
# Sim 9, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 9, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.006,  frw_df = 0.994
# Sim 10, t_n = 3, t = 3, t_1 = 4, T = 5: df = 0.995, Fwd = 0.005,  frw_df = 0.995
# Sim 10, t_n = 3, t = 4, t_1 = 5, T = 5: df = 0.987, Fwd = 0.006,  frw_df = 0.994
# Simulation 1, T_n = 3: Total Swap Value = 123.76335204742449
# Simulation 2, T_n = 3: Total Swap Value = 109.74888765349823
# Simulation 3, T_n = 3: Total Swap Value = 103.04684258751811
# Simulation 4, T_n = 3: Total Swap Value = 129.37249528438664
# Simulation 5, T_n = 3: Total Swap Value = 91.36807444596253
# Simulation 6, T_n = 3: Total Swap Value = 98.34486608018588
# Simulation 7, T_n = 3: Total Swap Value = 80.31241705373816
# Simulation 8, T_n = 3: Total Swap Value = 83.1750400308327
# Simulation 9, T_n = 3: Total Swap Value = 93.87716427372972
# Simulation 10, T_n = 3: Total Swap Value = 92.60651063154484
# Sim 1, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 2, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 3, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 4, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 5, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 6, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 7, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 8, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 9, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Sim 10, t_n = 4, t = 4, t_1 = 5, T = 5: df = 0.992, Fwd = 0.008,  frw_df = 0.992
# Simulation 1, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 2, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 3, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 4, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 5, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 6, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 7, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 8, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 9, T_n = 4: Total Swap Value = 65.14570637498771
# Simulation 10, T_n = 4: Total Swap Value = 65.14570637498771
